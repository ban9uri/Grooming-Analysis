# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
DC_URL="https://search.dcinside.com/combine/sort/accuracy/q/.EB.82.A8.EC.9E.90.20.EA.B4.80.EB.A6.AC"

list_index=['제목','날짜']
DC_list=[]

for num in range(1,10):


  Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36

# %%
import urllib.request
url_list=[]
with urllib.request.urlopen("https://search.dcinside.com/post/p/1/sort/accuracy/q/.EB.82.A8.EC.9E.90.20.EA.B4.80.EB.A6.AC") as url:
    doc = url.read()
    soup = BeautifulSoup(doc, "html.parser")
    results=soup.find("ul", class_="sch_result_list").find_all("li")
    for result in results:
      url_list.append(result.find("a")["href"])
url_list


for base_url in url_list:
      with urllib.request.urlopen(base_url) as url:
        doc = url.read()
        soup = BeautifulSoup(doc, "html.parser")
        print(base_url)


        # 기사 타이틀 수집
        title = soup.find_all("span", class_="title_subject")
        title_name=title[0].text
        print(title_name)
        #meaning = soup.find_all("ul", class_="list_mean")[0].find_all("span", class_="txt_mean")




        # # 기사 본문 수집
        # div = soup.find_all("div", class_="writing_view_box")
        # unwanted = div.find_all("figure")
        # # if unwanted:
        # #     for uw in unwanted:
        # #         uw.extract()
        # body = div.text.strip()
        # print(body)
# Out:
# https://gall.dcinside.com/mgallery/board/view/?id=mf&no=314420
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-b029151c967c> in <module>
#      18         # 기사 타이틀 수집
#      19         title = soup.find_all("span", class_="title_subject")
# ---> 20         title_name=title[0].text
#      21         print(title_name)
#      22         #meaning = soup.find_all("ul", class_="list_mean")[0].find_all("span", class_="txt_mean")
#
# IndexError: list index out of range

# %%
with urllib.request.urlopen(url_list[0]) as url:
        doc = url.read()
        soup = BeautifulSoup(doc, "html.parser")
        print(base_url)

        # 기사 타이틀 수집
        title = soup.find("span", class_="title_subject")
        print(title)
# Out:
# https://gall.dcinside.com/mgallery/board/view/?id=mf&no=314420
# None
