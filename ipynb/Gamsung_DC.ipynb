# %%
from pororo import Pororo

# %%
sa_shop = Pororo(task='sentiment', model='brainbert.base.ko.shopping', lang='ko')
sa = Pororo(task="sentiment", model="brainbert.base.ko.nsmc", lang="ko")

# %%
import pandas as pd
df = pd.read_excel("dc crawling.xlsx")

# %%
df
# Out:
#                                                comment
# 0    간혹 갤에 남자관리 뭐해야되냐 물어보는 패붕이들 있어서 적어봄 어짜피 이래도 잘생기...
# 1    굴러오지 않음. 너나 나나 금수저는 아니니까 그리고 관리 했고 만날 기회가 생겼을때...
# 2    요즘은 1020대 남자들이 대부분 관리를 열심히한다 한국에 방문한 타국가 사람들 또...
# 3    남자인 내가봐도 자연인 상태로 돌아다니는 한남들 많은데 좀만 꾸며도 다른 한남들은 ...
# 4    다들 관리해라 지금 05년생 고2이랑 99년생 만나는중인데 애들이 먼저 좋다고 들이...
# ..                                                 ...
# 973  결혼했다치자 와이프한테 사랑받아야지 도망가면어캄 운동주기적으로하고 피부과는가야함 임...
# 974  이건 본능임. 여자가 늙은 남자 만난다는 건........ 돈때문이지 뭐겠냐? 근데...
# 975  애 낳으면 실제로 들어가는 돈이 꽤 많아서 남자가 쓰는 용돈이 많지 않음 물론 여자...
# 976  노하우 터득하는곳은 여자가 빨랏음 여자들은 기본적으로 몇일만 지나도 일할자세가 되어...
# 977                  나 모르게 관리해줬으면 좋겟어 루틴 아는 순간 먼가 정떨어져
#
# [978 rows x 1 columns]

# %%
comment = []
for i in range(len(df.comment)):
    if len(df.comment[i]) <= 512:
        comment.append(df.comment[i])

sentiment = []
for i in range(len(comment)):
    sentiment.append(sa(comment[i]))

positive = []
for i in range(len(comment)):
    positive.append(sa(comment[i], show_probs=True)['positive'])

negative = []
for i in range(len(comment)):
    negative.append(sa(comment[i], show_probs=True)['negative'])

df_new = pd.DataFrame()
df_new["comment"] = comment
df_new["sentiment"] = sentiment
df_new["positive"] = positive
df_new["negative"] = negative

for_df = []

for i in range(len(df_new["comment"])):
    if df_new.iloc[i][1] == 'Positive':
        if df_new.iloc[i][2] >= 0.85:
            for_df.append(df_new.iloc[i])
    elif df_new.iloc[i][1] == 'Negative':
        if df_new.iloc[i][3] >= 0.85:
            for_df.append(df_new.iloc[i])

print("필터링 된 댓글의 수:", len(for_df))

df_new2 = pd.DataFrame(for_df)
df_new2
# Out:
# 필터링 된 댓글의 수: 722
#                                                comment sentiment  positive  \
# 0    간혹 갤에 남자관리 뭐해야되냐 물어보는 패붕이들 있어서 적어봄 어짜피 이래도 잘생기...  Negative  0.050182
# 1    굴러오지 않음. 너나 나나 금수저는 아니니까 그리고 관리 했고 만날 기회가 생겼을때...  Negative  0.003987
# 2    요즘은 1020대 남자들이 대부분 관리를 열심히한다 한국에 방문한 타국가 사람들 또...  Positive  0.874414
# 3    남자인 내가봐도 자연인 상태로 돌아다니는 한남들 많은데 좀만 꾸며도 다른 한남들은 ...  Negative  0.072764
# 6    그러니까. 남자관리 표정썩드라. 또 몇시간 후에 그 남자관리가 나 타층보낼라그러니까...  Negative  0.029607
# ..                                                 ...       ...       ...
# 972             ㅍㅌㅊ에서 ㅍㅅㅌㅊ 가능????? 관리 할게 뭐있지?? 피부? 운동?  Negative  0.039532
# 973  결혼했다치자 와이프한테 사랑받아야지 도망가면어캄 운동주기적으로하고 피부과는가야함 임...  Negative  0.091243
# 974  이건 본능임. 여자가 늙은 남자 만난다는 건........ 돈때문이지 뭐겠냐? 근데...  Negative  0.002065
# 975  애 낳으면 실제로 들어가는 돈이 꽤 많아서 남자가 쓰는 용돈이 많지 않음 물론 여자...  Negative  0.045870
# 976  노하우 터득하는곳은 여자가 빨랏음 여자들은 기본적으로 몇일만 지나도 일할자세가 되어...  Negative  0.148829
#
#      negative
# 0    0.949818
# 1    0.996013
# 2    0.125586
# 3    0.927236
# 6    0.970393
# ..        ...
# 972  0.960468
# 973  0.908757
# 974  0.997935
# 975  0.954130
# 976  0.851171
#
# [722 rows x 4 columns]

# %%
condition_ps = (df_new2.sentiment == "Positive")
condition_ng = (df_new2.sentiment == "Negative")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 condition_ps = (df_new2.sentiment == "Positive")
#       2 condition_ng = (df_new2.sentiment == "Negative")
#
# NameError: name 'df_new2' is not defined

# %%
df_positive = df_new2[condition_ps]
df_negative = df_new2[condition_ng]

# %%
df_positive.to_csv('dc_positive.csv', encoding='utf-8-sig') 
df_negative.to_csv('dc_negative.csv', encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_positive.to_csv('dc_positive.csv', encoding='utf-8-sig')
#       2 df_negative.to_csv('dc_negative.csv', encoding='utf-8-sig')
#
# NameError: name 'df_positive' is not defined
