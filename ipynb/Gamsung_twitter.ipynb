# %%
from pororo import Pororo

# %%
sa_shop = Pororo(task='sentiment', model='brainbert.base.ko.shopping', lang='ko')
sa = Pororo(task="sentiment", model="brainbert.base.ko.nsmc", lang="ko")

# %%
import pandas as pd
df = pd.read_csv("twitter crawling.csv")

# %%
df
# Out:
#       Unnamed: 0                       Date             User       Nickname  \
# 0              0  2022-09-08 13:40:23+00:00        dmjgongye          다공적목계
# 1              1  2022-04-27 05:23:44+00:00          sohveve  🎉지옥애서 온 민트하루👑
# 2              2  2022-09-10 18:27:38+00:00      2_lifeKnife        🖤 야마스피너
# 3              3  2022-05-18 15:33:17+00:00  dontkillmyocean             지구
# 4              4  2022-10-20 02:31:40+00:00          cch1994             캐논
# ...          ...                        ...              ...            ...
# 1995        1995  2018-11-14 10:26:37+00:00          bbb8627           김김채소
# 1996        1996  2018-01-06 12:28:40+00:00      bwv869oliva            라호야
# 1997        1997  2018-08-08 17:54:34+00:00  BJktxaVALIi4sG3           보이루~
# 1998        1998  2018-12-12 02:41:38+00:00       dkrkal0809           증사찍기
# 1999        1999  2018-05-17 05:48:05+00:00       mcwannabee            워너비
#
#                                                   Tweet  \
# 0     신떤여자 화장한 남자를 남자로 느끼지못하는이유가 주변 남자들 열이면아홉은 게이라서 ...
# 1     노CC에서 여심은 굉장히 예쁜애들이 많은데  남심은...........이래서 남자들...
# 2     @MMoong_CM 열바더 ㅇ아오 아...아니근데 무색무취 이거너무그...하.......
# 3     운동 꾸준히 하는 남자\n: 부지런하며 자기관리를 놓지 않는것 같아서 호감 상승 그...
# 4              @berlinmingming 화장안하면 남자아니냐??이게 여자얼굴이야??
# ...                                                 ...
# 1995  하다하다 뭐 저런 일까지 생겨..?? 진짜 뭔 논리야 화장안해서 페미같으니 죽인다고...
# 1996  사실 우리딸 포함, 울 동네도 중고등학교 여자애들이 마스크끼고 등하교하는데 남자애들...
# 1997  @OpU7l0PWt70qJci 언제는 남자들때문에 화장하는거 아니라면서요..? 페미...
# 1998  친구가 화장이 여자 특권이래 친구야.............네가 화장 안 하면 잒에 ...
# 1999  많은 일반인이 운동에 식이요법과 씨름하고, 대다수 연예인이 체중관리는 기본이고, 모...
#
#                                                     URL
# 0     https://twitter.com/dmjgongye/status/156787046...
# 1     https://twitter.com/sohveve/status/15191855066...
# 2     https://twitter.com/2_lifeKnife/status/1568667...
# 3     https://twitter.com/dontkillmyocean/status/152...
# 4     https://twitter.com/cch1994/status/15829224703...
# ...                                                 ...
# 1995  https://twitter.com/bbb8627/status/10626530189...
# 1996  https://twitter.com/bwv869oliva/status/9496187...
# 1997  https://twitter.com/BJktxaVALIi4sG3/status/102...
# 1998  https://twitter.com/dkrkal0809/status/10726828...
# 1999  https://twitter.com/mcwannabee/status/99699072...
#
# [2000 rows x 6 columns]

# %%
comment = []
for i in range(len(df.Tweet)):
    if len(df.Tweet[i]) <= 512:
        comment.append(df.Tweet[i])

sentiment = []
for i in range(len(comment)):
    sentiment.append(sa(comment[i]))

positive = []
for i in range(len(comment)):
    positive.append(sa(comment[i], show_probs=True)['positive'])

negative = []
for i in range(len(comment)):
    negative.append(sa(comment[i], show_probs=True)['negative'])

df_new = pd.DataFrame()
df_new["comment"] = comment
df_new["sentiment"] = sentiment
df_new["positive"] = positive
df_new["negative"] = negative

for_df = []

for i in range(len(df_new["comment"])):
    if df_new.iloc[i][1] == 'Positive':
        if df_new.iloc[i][2] >= 0.85:
            for_df.append(df_new.iloc[i])
    elif df_new.iloc[i][1] == 'Negative':
        if df_new.iloc[i][3] >= 0.85:
            for_df.append(df_new.iloc[i])

print("필터링 된 댓글의 수:", len(for_df))

df_new2 = pd.DataFrame(for_df)
df_new2
# Out:
# 필터링 된 댓글의 수: 1411
#                                                 comment sentiment  positive  \
# 0     신떤여자 화장한 남자를 남자로 느끼지못하는이유가 주변 남자들 열이면아홉은 게이라서 ...  Negative  0.082346
# 1     노CC에서 여심은 굉장히 예쁜애들이 많은데  남심은...........이래서 남자들...  Negative  0.001823
# 2     @MMoong_CM 열바더 ㅇ아오 아...아니근데 무색무취 이거너무그...하.......  Positive  0.926546
# 5     @:에타에서 화장하는 남자 어떻다저떻다 싸움 낫는데 일침 개웃김ㅠㅠ https://...  Positive  0.943399
# 6     머리가 길면 관리하는데 손이 갈 수밖에 없는데, 다른 전사분들은 남자신데도 그런 자...  Positive  0.989975
# ...                                                 ...       ...       ...
# 1995  하다하다 뭐 저런 일까지 생겨..?? 진짜 뭔 논리야 화장안해서 페미같으니 죽인다고...  Negative  0.001538
# 1996  사실 우리딸 포함, 울 동네도 중고등학교 여자애들이 마스크끼고 등하교하는데 남자애들...  Negative  0.050959
# 1997  @OpU7l0PWt70qJci 언제는 남자들때문에 화장하는거 아니라면서요..? 페미...  Negative  0.003533
# 1998  친구가 화장이 여자 특권이래 친구야.............네가 화장 안 하면 잒에 ...  Negative  0.003769
# 1999  많은 일반인이 운동에 식이요법과 씨름하고, 대다수 연예인이 체중관리는 기본이고, 모...  Negative  0.005097
#
#       negative
# 0     0.917654
# 1     0.998177
# 2     0.073454
# 5     0.056601
# 6     0.010025
# ...        ...
# 1995  0.998462
# 1996  0.949041
# 1997  0.996467
# 1998  0.996231
# 1999  0.994903
#
# [1411 rows x 4 columns]

# %%
condition_ps = (df_new2.sentiment == "Positive")
condition_ng = (df_new2.sentiment == "Negative")

# %%
df_positive = df_new2[condition_ps]
df_negative = df_new2[condition_ng]

# %%
df_positive.to_csv('twitter_positive.csv', encoding='utf-8-sig') 
df_negative.to_csv('twitter_negative.csv', encoding='utf-8-sig')
